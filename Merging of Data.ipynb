# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('CookingSessions.csv')

# %%
df2 = pd.read_csv('OrderDetails.csv')

# %%
df3 = pd.read_csv('UserDetails.csv')

# %%
df1.head()
# Out:
#   Session ID User ID        Dish Name  Meal Type     Session Start  \
# 0       S001    U001        Spaghetti     Dinner  2024-12-01 19:00
# 1       S002    U002     Caesar Salad      Lunch  2024-12-01 12:00
# 2       S003    U003  Grilled Chicken     Dinner  2024-12-02 19:30
# 3       S004    U001         Pancakes  Breakfast  2024-12-02 07:30
# 4       S005    U004     Caesar Salad      Lunch  2024-12-03 13:00
#
#         Session End  Duration (mins)  Session Rating
# 0  2024-12-01 19:30               30             4.5
# 1  2024-12-01 12:20               20             4.0
# 2  2024-12-02 20:10               40             4.8
# 3  2024-12-02 08:00               30             4.2
# 4  2024-12-03 13:15               15             4.7

# %%
df2.head()
# Out:
#    Order ID User ID  Order Date  Meal Type        Dish Name Order Status  \
# 0      1001    U001  2024-12-01     Dinner        Spaghetti    Completed
# 1      1002    U002  2024-12-01      Lunch     Caesar Salad    Completed
# 2      1003    U003  2024-12-02     Dinner  Grilled Chicken     Canceled
# 3      1004    U001  2024-12-02  Breakfast         Pancakes    Completed
# 4      1005    U004  2024-12-03      Lunch     Caesar Salad    Completed
#
#    Amount (USD) Time of Day  Rating Session ID
# 0          15.0       Night     5.0       S001
# 1          10.0         Day     4.0       S002
# 2          12.5       Night     NaN       S003
# 3           8.0     Morning     4.0       S004
# 4           9.0         Day     4.0       S005

# %%
df3.head()
# Out:
#   User ID      User Name  Age       Location Registration Date         Phone  \
# 0    U001  Alice Johnson   28       New York        2023-01-15  123-456-7890
# 1    U002      Bob Smith   35    Los Angeles        2023-02-20  987-654-3210
# 2    U003    Charlie Lee   42        Chicago        2023-03-10  555-123-4567
# 3    U004    David Brown   27  San Francisco        2023-04-05  444-333-2222
# 4    U005     Emma White   30        Seattle        2023-05-22  777-888-9999
#
#                Email Favorite Meal  Total Orders
# 0    alice@email.com        Dinner            12
# 1      bob@email.com         Lunch             8
# 2  charlie@email.com     Breakfast            15
# 3    david@email.com        Dinner            10
# 4     emma@email.com         Lunch             9

# %%
# merging of tables on user id
merged_table = df1.merge(df2, on='User ID', how='inner')

# %%
print(merged_table)
# Out:
#    Session ID_x User ID      Dish Name_x Meal Type_x     Session Start  \
# 0          S001    U001        Spaghetti      Dinner  2024-12-01 19:00
# 1          S001    U001        Spaghetti      Dinner  2024-12-01 19:00
# 2          S001    U001        Spaghetti      Dinner  2024-12-01 19:00
# 3          S002    U002     Caesar Salad       Lunch  2024-12-01 12:00
# 4          S002    U002     Caesar Salad       Lunch  2024-12-01 12:00
# 5          S002    U002     Caesar Salad       Lunch  2024-12-01 12:00
# 6          S003    U003  Grilled Chicken      Dinner  2024-12-02 19:30
# 7          S003    U003  Grilled Chicken      Dinner  2024-12-02 19:30
# 8          S003    U003  Grilled Chicken      Dinner  2024-12-02 19:30
# 9          S004    U001         Pancakes   Breakfast  2024-12-02 07:30
# 10         S004    U001         Pancakes   Breakfast  2024-12-02 07:30
# 11         S004    U001         Pancakes   Breakfast  2024-12-02 07:30
# ...

# %%
merged_table.head()
# Out:
#   Session ID_x User ID   Dish Name_x Meal Type_x     Session Start  \
# 0         S001    U001     Spaghetti      Dinner  2024-12-01 19:00
# 1         S001    U001     Spaghetti      Dinner  2024-12-01 19:00
# 2         S001    U001     Spaghetti      Dinner  2024-12-01 19:00
# 3         S002    U002  Caesar Salad       Lunch  2024-12-01 12:00
# 4         S002    U002  Caesar Salad       Lunch  2024-12-01 12:00
#
#         Session End  Duration (mins)  Session Rating  Order ID  Order Date  \
# 0  2024-12-01 19:30               30             4.5      1001  2024-12-01
# 1  2024-12-01 19:30               30             4.5      1004  2024-12-02
# 2  2024-12-01 19:30               30             4.5      1009  2024-12-05
# 3  2024-12-01 12:20               20             4.0      1002  2024-12-01
# 4  2024-12-01 12:20               20             4.0      1006  2024-12-03
#
#   Meal Type_y      Dish Name_y Order Status  Amount (USD) Time of Day  Rating  \
# ...

# %%
merged_table = merged_table.merge(df3, on = 'User ID', how = 'inner')

# %%
merged_table.head()
# Out:
#   Session ID_x User ID   Dish Name_x Meal Type_x     Session Start  \
# 0         S001    U001     Spaghetti      Dinner  2024-12-01 19:00
# 1         S001    U001     Spaghetti      Dinner  2024-12-01 19:00
# 2         S001    U001     Spaghetti      Dinner  2024-12-01 19:00
# 3         S002    U002  Caesar Salad       Lunch  2024-12-01 12:00
# 4         S002    U002  Caesar Salad       Lunch  2024-12-01 12:00
#
#         Session End  Duration (mins)  Session Rating  Order ID  Order Date  \
# 0  2024-12-01 19:30               30             4.5      1001  2024-12-01
# 1  2024-12-01 19:30               30             4.5      1004  2024-12-02
# 2  2024-12-01 19:30               30             4.5      1009  2024-12-05
# 3  2024-12-01 12:20               20             4.0      1002  2024-12-01
# 4  2024-12-01 12:20               20             4.0      1006  2024-12-03
#
#    ... Rating Session ID_y      User Name  Age     Location  \
# ...

# %%
merged_table.columns
# Out:
# Index(['Session ID_x', 'User ID', 'Dish Name_x', 'Meal Type_x',
#        'Session Start', 'Session End', 'Duration (mins)', 'Session Rating',
#        'Order ID', 'Order Date', 'Meal Type_y', 'Dish Name_y', 'Order Status',
#        'Amount (USD)', 'Time of Day', 'Rating', 'Session ID_y', 'User Name',
#        'Age', 'Location', 'Registration Date', 'Phone', 'Email',
#        'Favorite Meal', 'Total Orders'],
#       dtype='object')

# %%
merged_table['User Name'].value_counts()
# Out:
# User Name
# Alice Johnson    9
# Bob Smith        9
# Charlie Lee      9
# David Brown      4
# Emma White       4
# Frank Green      1
# Grace King       1
# Henry Lee        1
# Name: count, dtype: int64

# %%
merged_table['User ID'].value_counts()
# Out:
# User ID
# U001    9
# U002    9
# U003    9
# U004    4
# U005    4
# U006    1
# U007    1
# U008    1
# Name: count, dtype: int64

# %%
merged_table.isnull().sum()
# Out:
# Session ID_x         0
# User ID              0
# Dish Name_x          0
# Meal Type_x          0
# Session Start        0
# Session End          0
# Duration (mins)      0
# Session Rating       0
# Order ID             0
# Order Date           0
# Meal Type_y          0
# Dish Name_y          0
# Order Status         0
# Amount (USD)         0
# Time of Day          0
# Rating               6
# Session ID_y         0
# User Name            0
# Age                  0
# Location             0
# Registration Date    0
# Phone                0
# Email                0
# Favorite Meal        0
# Total Orders         0
# dtype: int64

# %%
merged_table['Session ID_y'].value_counts()
# Out:
# Session ID_y
# S001    3
# S004    3
# S009    3
# S002    3
# S006    3
# S010    3
# S003    3
# S008    3
# S011    3
# S005    2
# S012    2
# S007    2
# S013    2
# S014    1
# S015    1
# S016    1
# Name: count, dtype: int64

# %%
merged_table['Session ID_x'].value_counts()
# Out:
# Session ID_x
# S001    3
# S002    3
# S003    3
# S004    3
# S006    3
# S008    3
# S009    3
# S010    3
# S011    3
# S005    2
# S007    2
# S012    2
# S013    2
# S014    1
# S015    1
# S016    1
# Name: count, dtype: int64

# %%
merged_table.groupby('User Name')['Session ID_x'].value_counts()
# Out:
# User Name      Session ID_x
# Alice Johnson  S001            3
#                S004            3
#                S009            3
# Bob Smith      S002            3
#                S006            3
#                S010            3
# Charlie Lee    S003            3
#                S008            3
#                S011            3
# David Brown    S005            2
#                S012            2
# Emma White     S007            2
#                S013            2
# Frank Green    S014            1
# Grace King     S015            1
# Henry Lee      S016            1
# Name: count, dtype: int64

# %%
merged_table.groupby('User Name')['Session ID_y'].value_counts()
# Out:
# User Name      Session ID_y
# Alice Johnson  S001            3
#                S004            3
#                S009            3
# Bob Smith      S002            3
#                S006            3
#                S010            3
# Charlie Lee    S003            3
#                S008            3
#                S011            3
# David Brown    S005            2
#                S012            2
# Emma White     S007            2
#                S013            2
# Frank Green    S014            1
# Grace King     S015            1
# Henry Lee      S016            1
# Name: count, dtype: int64

# %%
# dropping the repeated column
merged_table.drop('Session ID_y',axis=1, inplace= True)

# %%
merged_table.head()
# Out:
#   Session ID_x User ID   Dish Name_x Meal Type_x     Session Start  \
# 0         S001    U001     Spaghetti      Dinner  2024-12-01 19:00
# 1         S001    U001     Spaghetti      Dinner  2024-12-01 19:00
# 2         S001    U001     Spaghetti      Dinner  2024-12-01 19:00
# 3         S002    U002  Caesar Salad       Lunch  2024-12-01 12:00
# 4         S002    U002  Caesar Salad       Lunch  2024-12-01 12:00
#
#         Session End  Duration (mins)  Session Rating  Order ID  Order Date  \
# 0  2024-12-01 19:30               30             4.5      1001  2024-12-01
# 1  2024-12-01 19:30               30             4.5      1004  2024-12-02
# 2  2024-12-01 19:30               30             4.5      1009  2024-12-05
# 3  2024-12-01 12:20               20             4.0      1002  2024-12-01
# 4  2024-12-01 12:20               20             4.0      1006  2024-12-03
#
#    ... Rating      User Name Age     Location Registration Date         Phone  \
# ...

# %%
merged_table['Dish Name_x'].value_counts()
# Out:
# Dish Name_x
# Spaghetti          9
# Grilled Chicken    9
# Caesar Salad       7
# Pancakes           6
# Veggie Burger      4
# Oatmeal            3
# Name: count, dtype: int64

# %%
merged_table['Meal Type_x'].value_counts()
# Out:
# Meal Type_x
# Dinner       18
# Lunch        11
# Breakfast     9
# Name: count, dtype: int64

# %%
merged_table['Dish Name_y'].value_counts()
# Out:
# Dish Name_y
# Spaghetti          9
# Grilled Chicken    9
# Caesar Salad       7
# Pancakes           6
# Veggie Burger      4
# Oatmeal            3
# Name: count, dtype: int64

# %%
merged_table['Meal Type_y'].value_counts()
# Out:
# Meal Type_y
# Dinner       18
# Lunch        11
# Breakfast     9
# Name: count, dtype: int64

# %%
# dropping the repeated column
merged_table.drop('Meal Type_y',axis=1, inplace=True)
merged_table.drop('Dish Name_y',axis=1, inplace=True)

# %%
merged_table.head()
# Out:
#   Session ID_x User ID   Dish Name_x Meal Type_x     Session Start  \
# 0         S001    U001     Spaghetti      Dinner  2024-12-01 19:00
# 1         S001    U001     Spaghetti      Dinner  2024-12-01 19:00
# 2         S001    U001     Spaghetti      Dinner  2024-12-01 19:00
# 3         S002    U002  Caesar Salad       Lunch  2024-12-01 12:00
# 4         S002    U002  Caesar Salad       Lunch  2024-12-01 12:00
#
#         Session End  Duration (mins)  Session Rating  Order ID  Order Date  \
# 0  2024-12-01 19:30               30             4.5      1001  2024-12-01
# 1  2024-12-01 19:30               30             4.5      1004  2024-12-02
# 2  2024-12-01 19:30               30             4.5      1009  2024-12-05
# 3  2024-12-01 12:20               20             4.0      1002  2024-12-01
# 4  2024-12-01 12:20               20             4.0      1006  2024-12-03
#
#    ... Rating      User Name Age     Location Registration Date         Phone  \
# ...

# %%
# renaming the column
merged_table.rename(columns={'Session ID_x':'Session ID'},inplace=True)

# %%
merged_table.rename(columns={'Dish Name_x':'Dish Name'},inplace=True)
merged_table.rename(columns={'Meal Type_x':'Meal Type'},inplace=True)

# %%
merged_table.columns
# Out:
# Index(['Session ID', 'User ID', 'Dish Name', 'Meal Type', 'Session Start',
#        'Session End', 'Duration (mins)', 'Session Rating', 'Order ID',
#        'Order Date', 'Order Status', 'Amount (USD)', 'Time of Day', 'Rating',
#        'User Name', 'Age', 'Location', 'Registration Date', 'Phone', 'Email',
#        'Favorite Meal', 'Total Orders', 'Comparison'],
#       dtype='object')

# %%
merged_table.isnull().sum()
# Out:
# Session ID           0
# User ID              0
# Dish Name            0
# Meal Type            0
# Session Start        0
# Session End          0
# Duration (mins)      0
# Session Rating       0
# Order ID             0
# Order Date           0
# Order Status         0
# Amount (USD)         0
# Time of Day          0
# Rating               6
# User Name            0
# Age                  0
# Location             0
# Registration Date    0
# Phone                0
# Email                0
# Favorite Meal        0
# Total Orders         0
# Comparison           0
# dtype: int64

# %%
#Saving the all three tables combined to a single csv
merged_table.to_csv('combined.csv', index=False)

print("CSV file saved as 'custom_name.csv'!")
# Out:
# CSV file saved as 'custom_name.csv'!
